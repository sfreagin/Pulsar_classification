# %%
import pandas as pd
import numpy as np

# %%
column_headers = ['mean','st_dev','exc_kurtosis','skewness','dm_mean','dmst_dev','dmexc_kurtosis','dmskewness','pulsar']

# %%
pulsar_df = pd.read_csv("../dataset/HTRU_2.csv",names=column_headers)

# %%
pulsar_df
# Out:
#              mean     st_dev  exc_kurtosis  skewness     dm_mean   dmst_dev  \
# 0      140.562500  55.683782     -0.234571 -0.699648    3.199833  19.110426
# 1      102.507812  58.882430      0.465318 -0.515088    1.677258  14.860146
# 2      103.015625  39.341649      0.323328  1.051164    3.121237  21.744669
# 3      136.750000  57.178449     -0.068415 -0.636238    3.642977  20.959280
# 4       88.726562  40.672225      0.600866  1.123492    1.178930  11.468720
# ...           ...        ...           ...       ...         ...        ...
# 17893  136.429688  59.847421     -0.187846 -0.738123    1.296823  12.166062
# 17894  122.554688  49.485605      0.127978  0.323061   16.409699  44.626893
# 17895  119.335938  59.935939      0.159363 -0.743025   21.430602  58.872000
# 17896  114.507812  53.902400      0.201161 -0.024789    1.946488  13.381731
# 17897   57.062500  85.797340      1.406391  0.089520  188.306020  64.712562
#
#        dmexc_kurtosis  dmskewness  pulsar
# 0            7.975532   74.242225       0
# 1           10.576487  127.393580       0
# 2            7.735822   63.171909       0
# 3            6.896499   53.593661       0
# 4           14.269573  252.567306       0
# ...               ...         ...     ...
# 17893       15.450260  285.931022       0
# 17894        2.945244    8.297092       0
# 17895        2.499517    4.595173       0
# 17896       10.007967  134.238910       0
# 17897       -1.597527    1.429475       0
#
# [17898 rows x 9 columns]

# %%
pulsar_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17898 entries, 0 to 17897
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   mean            17898 non-null  float64
#  1   st_dev          17898 non-null  float64
#  2   exc_kurtosis    17898 non-null  float64
#  3   skewness        17898 non-null  float64
#  4   dm_mean         17898 non-null  float64
#  5   dmst_dev        17898 non-null  float64
#  6   dmexc_kurtosis  17898 non-null  float64
#  7   dmskewness      17898 non-null  float64
#  8   pulsar          17898 non-null  int64
# dtypes: float64(8), int64(1)
# memory usage: 1.2 MB

# %%
pulsar_df.describe()
# Out:
#                mean        st_dev  exc_kurtosis      skewness       dm_mean  \
# count  17898.000000  17898.000000  17898.000000  17898.000000  17898.000000
# mean     111.079968     46.549532      0.477857      1.770279     12.614400
# std       25.652935      6.843189      1.064040      6.167913     29.472897
# min        5.812500     24.772042     -1.876011     -1.791886      0.213211
# 25%      100.929688     42.376018      0.027098     -0.188572      1.923077
# 50%      115.078125     46.947479      0.223240      0.198710      2.801839
# 75%      127.085938     51.023202      0.473325      0.927783      5.464256
# max      192.617188     98.778911      8.069522     68.101622    223.392140
#
#            dmst_dev  dmexc_kurtosis    dmskewness        pulsar
# count  17898.000000    17898.000000  17898.000000  17898.000000
# mean      26.326515        8.303556    104.857709      0.091574
# std       19.470572        4.506092    106.514540      0.288432
# min        7.370432       -3.139270     -1.976976      0.000000
# 25%       14.437332        5.781506     34.960504      0.000000
# 50%       18.461316        8.433515     83.064556      0.000000
# 75%       28.428104       10.702959    139.309331      0.000000
# max      110.642211       34.539844   1191.000837      1.000000

# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Dense

from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn import metrics

# %%
sc = StandardScaler()

# %%
X = pulsar_df.drop(columns=['pulsar'])
y = pulsar_df['pulsar']

X_train, X_test, y_train, y_test = train_test_split(X,y, stratify=y,test_size=0.5)

# %%
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
model = Sequential()

# %%
model.add(Dense(8,input_dim=8,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(4,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy',metrics=['accuracy'])

# %%
model.fit(X_train_sc,y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 280/280 [==============================] - 1s 813us/step - loss: 0.5852 - accuracy: 0.6517
# Epoch 2/50
# 280/280 [==============================] - 0s 872us/step - loss: 0.1125 - accuracy: 0.9729
# Epoch 3/50
# 280/280 [==============================] - 0s 892us/step - loss: 0.0821 - accuracy: 0.9788
# Epoch 4/50
# 280/280 [==============================] - 0s 874us/step - loss: 0.0733 - accuracy: 0.9796
# Epoch 5/50
# 280/280 [==============================] - 0s 839us/step - loss: 0.0850 - accuracy: 0.9761
# Epoch 6/50
# 280/280 [==============================] - 0s 934us/step - loss: 0.0699 - accuracy: 0.9810
# Epoch 7/50
# 280/280 [==============================] - 0s 870us/step - loss: 0.0677 - accuracy: 0.9808
# Epoch 8/50
# 280/280 [==============================] - 0s 807us/step - loss: 0.0637 - accuracy: 0.9830
# Epoch 9/50
# 280/280 [==============================] - 0s 853us/step - loss: 0.0694 - accuracy: 0.9789
# Epoch 10/50
# 280/280 [==============================] - 0s 819us/step - loss: 0.0749 - accuracy: 0.9796
# Epoch 11/50
# 280/280 [==============================] - 0s 855us/step - loss: 0.0725 - accuracy: 0.9799
# Epoch 12/50
# 280/280 [==============================] - 0s 874us/step - loss: 0.0620 - accuracy: 0.9819
# Epoch 13/50
# 280/280 [==============================] - 0s 821us/step - loss: 0.0677 - accuracy: 0.9795
# Epoch 14/50
# 280/280 [==============================] - 0s 858us/step - loss: 0.0693 - accuracy: 0.9797
# Epoch 15/50
# 280/280 [==============================] - 0s 864us/step - loss: 0.0634 - accuracy: 0.9802
# Epoch 16/50
# 280/280 [==============================] - 0s 862us/step - loss: 0.0659 - accuracy: 0.9794
# Epoch 17/50
# 280/280 [==============================] - 0s 837us/step - loss: 0.0691 - accuracy: 0.9787
# Epoch 18/50
# 280/280 [==============================] - 0s 864us/step - loss: 0.0643 - accuracy: 0.9805
# Epoch 19/50
# 280/280 [==============================] - 0s 847us/step - loss: 0.0630 - accuracy: 0.9816
# Epoch 20/50
# 280/280 [==============================] - 0s 852us/step - loss: 0.0585 - accuracy: 0.9807
# Epoch 21/50
# 280/280 [==============================] - 0s 835us/step - loss: 0.0660 - accuracy: 0.9804
# Epoch 22/50
# 280/280 [==============================] - 0s 852us/step - loss: 0.0593 - accuracy: 0.9828
# Epoch 23/50
# 280/280 [==============================] - 0s 852us/step - loss: 0.0566 - accuracy: 0.9838
# Epoch 24/50
# 280/280 [==============================] - 0s 885us/step - loss: 0.0713 - accuracy: 0.9770
# Epoch 25/50
# 280/280 [==============================] - 0s 881us/step - loss: 0.0619 - accuracy: 0.9797
# Epoch 26/50
# 280/280 [==============================] - 0s 842us/step - loss: 0.0663 - accuracy: 0.9803
# Epoch 27/50
# 280/280 [==============================] - 0s 840us/step - loss: 0.0657 - accuracy: 0.9804
# Epoch 28/50
# 280/280 [==============================] - 0s 876us/step - loss: 0.0629 - accuracy: 0.9808
# Epoch 29/50
# 280/280 [==============================] - 0s 876us/step - loss: 0.0558 - accuracy: 0.9841
# Epoch 30/50
# 280/280 [==============================] - 0s 855us/step - loss: 0.0640 - accuracy: 0.9809
# Epoch 31/50
# 280/280 [==============================] - 0s 850us/step - loss: 0.0627 - accuracy: 0.9804
# Epoch 32/50
# 280/280 [==============================] - 0s 856us/step - loss: 0.0659 - accuracy: 0.9777
# Epoch 33/50
# 280/280 [==============================] - 0s 843us/step - loss: 0.0546 - accuracy: 0.9830
# Epoch 34/50
# 280/280 [==============================] - 0s 879us/step - loss: 0.0577 - accuracy: 0.9832
# Epoch 35/50
# 280/280 [==============================] - 0s 844us/step - loss: 0.0654 - accuracy: 0.9791
# Epoch 36/50
# 280/280 [==============================] - 0s 867us/step - loss: 0.0628 - accuracy: 0.9814
# Epoch 37/50
# 280/280 [==============================] - 0s 855us/step - loss: 0.0546 - accuracy: 0.9831
# Epoch 38/50
# 280/280 [==============================] - 0s 859us/step - loss: 0.0594 - accuracy: 0.9818
# Epoch 39/50
# 280/280 [==============================] - 0s 851us/step - loss: 0.0545 - accuracy: 0.9828
# Epoch 40/50
# 280/280 [==============================] - 0s 849us/step - loss: 0.0636 - accuracy: 0.9811
# Epoch 41/50
# 280/280 [==============================] - 0s 855us/step - loss: 0.0585 - accuracy: 0.9821
# Epoch 42/50
# 280/280 [==============================] - 0s 851us/step - loss: 0.0610 - accuracy: 0.9816
# Epoch 43/50
# 280/280 [==============================] - 0s 856us/step - loss: 0.0620 - accuracy: 0.9826
# Epoch 44/50
# 280/280 [==============================] - 0s 860us/step - loss: 0.0561 - accuracy: 0.9818
# Epoch 45/50
# 280/280 [==============================] - 0s 868us/step - loss: 0.0562 - accuracy: 0.9815
# Epoch 46/50
# 280/280 [==============================] - 0s 856us/step - loss: 0.0594 - accuracy: 0.9821
# Epoch 47/50
# 280/280 [==============================] - 0s 844us/step - loss: 0.0621 - accuracy: 0.9796
# Epoch 48/50
# 280/280 [==============================] - 0s 840us/step - loss: 0.0595 - accuracy: 0.9823
# Epoch 49/50
# 280/280 [==============================] - 0s 868us/step - loss: 0.0556 - accuracy: 0.9831
# Epoch 50/50
# 280/280 [==============================] - 0s 838us/step - loss: 0.0660 - accuracy: 0.9798

# %%
model.evaluate(X_test_sc,y_test)
# Out:
# 280/280 [==============================] - 0s 658us/step - loss: 0.0696 - accuracy: 0.9802
# [0.06958364695310593, 0.9802212715148926]

# %%
y_preds = model.predict(X_test_sc)

y_preds = [ 1 if num >=0.5 else 0 for num in y_preds]

# %%
print(metrics.confusion_matrix(y_test,y_preds))
# Out:
# [[8068   61]
#  [ 116  704]]

# %%
print(metrics.classification_report(y_test,y_preds))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      8129
#            1       0.92      0.86      0.89       820
#
#     accuracy                           0.98      8949
#    macro avg       0.95      0.93      0.94      8949
# weighted avg       0.98      0.98      0.98      8949
